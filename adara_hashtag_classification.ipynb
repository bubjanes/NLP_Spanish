# %%
import pandas as pd
import numpy as np
from collections import Counter
import re 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords
from sklearn.naive_bayes import MultinomialNB

# %%
#load data
df = pd.read_csv("adara_corpus.csv")

# %%
#nltk.download('stopwords')
stop_words = stopwords.words("spanish")

# %%
#pre-processing (for later)
def clean_str(string):
    """
    Tokenization/string cleaning for dataset
    Every dataset is lower cased except
    """
    string = re.sub(r"\n", "", string)    
    string = re.sub(r"\r", "", string) 
    string = re.sub(r"[0-9]", "digit", string)
    string = re.sub(r"\'", "", string)    
    string = re.sub(r"\"", "", string)    
    return string.strip().lower()

# %%
df.head()
# Out:
#                    CreateAt           Hashtags type  \
# 0  2019-05-13T13:00:10.000Z                NaN    m
# 1  2019-05-13T13:00:12.000Z  #consulta_campaña    m
# 2  2019-05-13T16:36:13.000Z  #consulta_campaña    r
# 3  2019-05-20T15:35:29.000Z                NaN    r
# 4  2019-05-20T16:03:02.000Z                NaN    m
#
#                                              Mensaje  \
# 0  Soy de Córdoba capital no se de donde son ustedes
# 1             Quiero un turno de la Campaña Gratuita
# 2  Gracias por comunicarse con Adara!\n\nLe infor...
# 3  ¡Buenas tardes! Nos comunicamos nuevamente par...
# 4                            Hola. si. me encantaria
#
#                        UserId Name_2  UserName
# 0  7kut6fgex3du7xt7s38h43shqw  adara  whatsapp
# 1  7kut6fgex3du7xt7s38h43shqw  adara  whatsapp
# 2  ij6w4x8n9fbpxqxh79gj8474by  adara     adara
# 3  ij6w4x8n9fbpxqxh79gj8474by  adara     adara
# 4  7kut6fgex3du7xt7s38h43shqw  adara  whatsapp

# %%
Counter(df["Hashtags"])
# Out:
# Counter({'#cambiar_turno': 3,
#          '#consulta': 2,
#          '#consulta_campaña': 207,
#          '#dermatologia': 47,
#          '#deteccion_lunares': 1,
#          '#dr_falcon': 22,
#          '#dr_forni': 1,
#          '#dr_lamoratta': 31,
#          '#dr_morales ': 18,
#          '#dra_elorza': 6,
#          '#dra_forni': 5,
#          '#dra_pozzi': 2,
#          '#encuesta': 19,
#          '#escleroterapia': 5,
#          '#estetica': 15,
#          '#flebologia': 6,
#          '#flebologia ': 156,
#          '#gordura': 1,
#          '#lic_porchietto': 1,
#          '#lic_vazquez': 2,
#          '#lic_vazquez #dr_lamoratta': 1,
#          '#no_confirmado': 6,
#          '#nutricion': 5,
#          '#otro_servicio': 3,
#          '#pendiente_respuesta': 41,
#          '#queja': 2,
#          '#turno': 14,
#          '#turno_cancelado': 72,
#          '#turno_confirmado': 185,
#          '#turno_facebook': 6,
#          '#turno_reprogramado': 72,
#          nan: 2035})

# %% [markdown]
# ## deal with empty hashtag blocks

# %%
df['Hashtags'].head(10)
# Out:
# 0                  NaN
# 1    #consulta_campaña
# 2    #consulta_campaña
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7         #dr_morales
# 8                  NaN
# 9                  NaN
# Name: Hashtags, dtype: object

# %%
# rename all empty hashtag blocks
df['Hashtags'] = df['Hashtags'].fillna('blank')

# %%
le = LabelEncoder()

# %%
dfle = df.drop(['CreateAt', 'type', 'UserId', 'Name_2', 'UserName'], axis=1)
dfle.head(5)
# Out:
#             Hashtags                                            Mensaje
# 0              blank  Soy de Córdoba capital no se de donde son ustedes
# 1  #consulta_campaña             Quiero un turno de la Campaña Gratuita
# 2  #consulta_campaña  Gracias por comunicarse con Adara!\n\nLe infor...
# 3              blank  ¡Buenas tardes! Nos comunicamos nuevamente par...
# 4              blank                            Hola. si. me encantaria

# %% [markdown]
# ## Label Encoder: working with the dependent variable (Y)

# %%
dfle.Hashtags = le.fit_transform(dfle.Hashtags)
dfle.head(5)
# Out:
#    Hashtags                                            Mensaje
# 0        31  Soy de Córdoba capital no se de donde son ustedes
# 1         2             Quiero un turno de la Campaña Gratuita
# 2         2  Gracias por comunicarse con Adara!\n\nLe infor...
# 3        31  ¡Buenas tardes! Nos comunicamos nuevamente par...
# 4        31                            Hola. si. me encantaria

# %%
Y = dfle['Hashtags'].values
Y
# Out:
# array([31,  2,  2, ..., 31, 31,  3])

# %% [markdown]
# ##  Now let's work with the independent variable (X)

# %%
# do some cleaning of the text. all lower case
X = []
for i in range(dfle.shape[0]):
    strng = str(dfle.iloc[i][1])
    X.append(clean_str(strng))

# %% [markdown]
# ## TRAIN, TEST, SPLIT

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=5)

# %% [markdown]
# ## Vectorize: turn the messages into numbers

# %%
cv = CountVectorizer()

# %%
x_traincv=cv.fit_transform(x_train)
#x_testcv =cv.fit_transform(x_test)
x_traincv.shape
# Out:
# (2094, 1664)

# %%
# transform to an array
train_arrai = x_traincv.toarray()
#test_arrai  = x_testcv.toarray()
train_arrai.shape
# Out:
# (2094, 1664)

# %%
#cv.get_feature_names()

# %%
cv.inverse_transform(train_arrai[0])
# Out:
# [array(['con', 'contamos', 'de', 'digitdigit', 'digitdigitdigitdigit',
#         'disponibilidad', 'dr', 'días', 'lamoratta', 'los', 'morales',
#         'para', 'turno'], dtype='<U120')]

# %% [markdown]
# ## Naive Bayes classification

# %%
mnb=MultinomialNB()

# %%
###### for applying the Naive Bayes algorithm use "fit()"
mnb.fit(train_arrai, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# test data use "transform()"
x_testcv = cv.transform(x_test)
test_arrai  = x_testcv.toarray()

# %%
#predictions
pred = mnb.predict(test_arrai)
pred
# Out:
# array([31, 28, 31,  2, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#         2, 31, 31, 28, 31, 16, 31,  2, 31,  2, 28, 31, 31, 31, 31, 16, 31,
#        28, 31, 31, 31, 31, 31, 31, 16, 31, 31, 31, 31, 28, 28, 31, 31, 31,
#        31, 27, 31, 31,  2, 31, 31, 31, 31,  2, 16, 31,  2,  2,  2, 31, 31,
#        24, 31,  2, 31, 31, 31,  2, 31,  2, 31, 31, 31, 31, 31, 31, 31, 31,
#         2, 31, 31,  2, 31, 31, 31, 31, 31, 31, 28, 16, 31, 28, 27, 28,  3,
#        31, 31, 31, 27, 31, 31,  2, 31, 30, 28, 16, 31, 31, 31, 31, 31, 28,
#        31, 31,  2, 30, 31, 31, 31,  2, 31, 31, 16, 28, 31, 31, 31, 31, 31,
#        31,  3, 31, 31, 31, 27, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
 30, 31, 31, 31, 31, 31, 31, 31, 31, 31, 30, 31, 28, 31,
#        31, 31, 12, 28, 31,  3, 28, 31, 31,  2, 31, 27, 28, 31, 31, 31, 27,
#        31, 31,  7, 31, 31, 31, 31,  2, 12, 31,  2, 31, 31, 28, 31, 31, 31,
#        31, 31,  2, 31, 31, 31, 31, 28,  2, 31, 31, 28, 26, 31, 31, 31, 16,
#        31, 31,  2, 16, 31, 31, 31, 31, 31,  2, 31,  2, 31, 31, 31, 27, 31,
#        31, 29, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 16, 31, 31, 16, 31,
#        28, 31,  3, 31, 31, 31, 31, 31, 31, 31,  2,  8, 31,  2, 30,  7, 28,
#        16, 31, 31, 31, 31, 31, 31,  3, 31,  7, 28, 31, 16, 31])

# %%
count=0
for i in range (len(pred)):
    if pred[i]==actual[i]:
        count=count+1
print("We have",count,"correct predictions out of",len(pred),".")
print("Total",(count/len(pred))*100,"accuracy using Count Vectorizer.")
# Out:
# We have 661 correct predictions out of 898 .
# Total 73.60801781737194 accuracy using Count Vectorizer.

# %%
# preparing our results for a tabular visualization
messg = []
for msg in x_test:
    messg.append(msg)
predictions = []
for x in le.inverse_transform(pred):
    predictions.append(x)
original = []
for i in le.inverse_transform(y_test):
    original.append(i)

# %%
# this is the Original, hand labeled data
dataf = pd.DataFrame({'ORIGINAL_TYPE' : original,
                      'ML_PREDICT' : predictions,
                     'TEXT' : messg})
dataf
# Out:
#             ML_PREDICT        ORIGINAL_TYPE  \
# 0                blank                blank
# 1    #turno_confirmado    #turno_confirmado
# 2                blank                blank
# 3    #consulta_campaña    #consulta_campaña
# 4                blank                blank
# 5                blank                blank
# 6                blank                blank
# 7                blank                blank
# 8                blank                blank
# 9                blank                blank
# 10               blank                blank
# 11               blank                blank
# 12               blank                blank
# 13               blank                blank
# 14               blank                blank
# 15               blank                blank
# 16               blank                blank
# 17   #consulta_campaña                blank
# 18               blank                blank
# 19               blank    #turno_confirmado
# 20   #turno_confirmado    #turno_confirmado
# 21               blank                blank
# 22        #flebologia          #flebologia
# 23               blank                blank
# 24   #consulta_campaña    #consulta_campaña
# 25               blank        #dr_lamoratta
# 26   #consulta_campaña                blank
# 27   #turno_confirmado                blank
# 28               blank                blank
# 29               blank                blank
# ..                 ...                  ...
# 868              blank                blank
# 869              blank        #dermatologia
# 870  #consulta_campaña                blank
# 871              blank                blank
# 872              blank                blank
# 873              blank                blank
# 874              blank                blank
# 875              blank                blank
# 876              blank                blank
# 877  #consulta_campaña    #consulta_campaña
# 878              blank         #dr_morales
# 879              blank                blank
# 880  #consulta_campaña    #consulta_campaña
# 881              blank  #turno_reprogramado
# 882              blank        #dr_lamoratta
# 883  #turno_confirmado    #turno_confirmado
# 884              blank         #flebologia
# 885              blank                blank
# 886              blank                blank
# 887              blank                blank
# 888              blank                blank
# 889              blank                blank
# 890              blank                blank
# 891      #dermatologia        #dermatologia
# 892              blank                blank
# 893              blank        #dr_lamoratta
# 894  #turno_confirmado    #turno_confirmado
# 895              blank                blank
# 896              blank         #flebologia
# 897              blank                blank
#
#                                                   TEXT
# 0    leidys rojas dni digitdigit.digitdigitdigit.di...
# 1    muchas gracias, su turno ha sido confirmado.so...
# 2              hola puedo pedir un turno de la campaña
# 3    gracias por comunicarse con adara!le informamo...
# 4    verinia tupayachi dni digitdigitdigitdigitdigi...
# 5                                me decis la dirección
# 6    correcto, puede solicitar el turno personalmente.
# 7    podría ser digitdigit/digitdigit/digitdigitdig...
# 8                   trabajo de digitdigit a digitdigit
# 9                cuando me podrán otorgar un turno????
# 10                                                   ?
# 11                                             gracias
# 12                       francisco inalican digitdigit
# 13   hola soy cristina quiero un turno para el vier...
# 14                                       por la mañana
# 15                              por la mañana es mejor
# 16   clemira ortega digitdigit.digitdigitdigit.digi...
# 17                                     quiero un turno
# 18                                             gracias
# 19                                                  si
# 20   muchas gracias, su turno ha sido confirmado.so...
# 21                        y de que tratan los estudios
# 22                                      es flebologica
# 23                                a las digit si tenes
# 24   gracias por comunicarse con adara!le informamo...
# 25   perfecto liliana, la esperamos el día jueves d...
# 26              quiero un turno de la campaña gratuita
# 27   muchas gracias, su turno ha sido confirmado pa...
# 28                                         solo en dni
# 29                                           es iliana
# ..                                                 ...
# 868                                  soy edith ledesma
# 869  hola quiero un turno , para un lunar que tengo...
# 870  gracias por comunicarse con adara!le informamo...
# 871  una consulta,es doloroso,pregunto x el tema si...
# 872         perfecto, ¿este número a quién perteneces?
# 873  como le informaba anteriormente, para registra...
# 874                                          como hago
# 875                                por favor un turno.
# 876                                       el de javier
# 877  que es lo que cubre la compañía gratuita la pr...
# 878  perfecto rosana, ya registramos su turno para ...
# 879  contamos con disponibilidad de turno para los ...
# 880  gracias por comunicarse con adara!le informamo...
# 881  muchas gracias patricia, ya reprogramamos su t...
# 882                                 con el dr lamorata
# 883                                        si confirmo
# 884  ok mañana me comunico solicitó un turno gratui...
# 885                        para cuando tendria turno ?
# 886  el de la digitdigit:digitdigiths sería el más ...
# 887  buenas tardes paola, el próximo miércoles los ...
# 888                              claudia vanesa oviedo
# 889       flebologia  y si puedo ya solicitar un turno
# 890  contamos con disponibilidad de turno para los ...
# 891       quiero un turno para la detección de lunares
# 892                                      si es posible
# 893  miercoles digitdigit,digitdigitcon el dr.lamor...
# 894                    ok. muchas gracias. allí estaré
# 895  momentáneamente trabajamos con las siguientes ...
# 896  tengo un voucher por una consulta médica sin c...
# 897                 debo llevar estudios anteriores ??
#
# [898 rows x 3 columns]

# %%
# if you want to experiment, try writing something in the blank
mess = ["<type your message here>"]
message = cv.transform(mess)
messages = message.toarray()
predicted = mnb.predict(messages)
le.inverse_transform(predicted)
# Out:
# array(['#flebologia '], dtype=object)
